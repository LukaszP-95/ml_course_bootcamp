# %% [markdown]
# <a href="https://colab.research.google.com/github/LukaszP-95/ml_course_bootcamp/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Lukasz")
# Out:
# Hello Lukasz
